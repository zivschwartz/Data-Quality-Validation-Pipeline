# %%
import glob
import pandas as pd

# %%
flights = glob.glob('FLIGHTS/*.csv')
# DEBS = glob.glob(‘tmp/DEBS/*.csv’)
# FBPosts = glob.glob(‘tmp/FBPosts/*.csv’)
dirty_flights = []
clean_flights = []
for f in flights:
   if 'dirty' in f:
       dirty_flights.append(f)
   else:
       clean_flights.append(f)

# %%
dirty_flights
# Out:
# ['FLIGHTS/FLIGHTS_dirty_734500.csv',
#  'FLIGHTS/FLIGHTS_dirty_734474.csv',
#  'FLIGHTS/FLIGHTS_dirty_734475.csv',
#  'FLIGHTS/FLIGHTS_dirty_734501.csv',
#  'FLIGHTS/FLIGHTS_dirty_734503.csv',
#  'FLIGHTS/FLIGHTS_dirty_734488.csv',
#  'FLIGHTS/FLIGHTS_dirty_734476.csv',
#  'FLIGHTS/FLIGHTS_dirty_734489.csv',
#  'FLIGHTS/FLIGHTS_dirty_734502.csv',
#  'FLIGHTS/FLIGHTS_dirty_734499.csv',
#  'FLIGHTS/FLIGHTS_dirty_734472.csv',
#  'FLIGHTS/FLIGHTS_dirty_734473.csv',
#  'FLIGHTS/FLIGHTS_dirty_734498.csv',
#  'FLIGHTS/FLIGHTS_dirty_734505.csv',
#  'FLIGHTS/FLIGHTS_dirty_734504.csv',
#  'FLIGHTS/FLIGHTS_dirty_734482.csv',
#  'FLIGHTS/FLIGHTS_dirty_734496.csv',
#  'FLIGHTS/FLIGHTS_dirty_734497.csv',
#  'FLIGHTS/FLIGHTS_dirty_734483.csv',
#  'FLIGHTS/FLIGHTS_dirty_734495.csv',
#  'FLIGHTS/FLIGHTS_dirty_734481.csv',
#  'FLIGHTS/FLIGHTS_dirty_734480.csv',
#  'FLIGHTS/FLIGHTS_dirty_734490.csv',
#  'FLIGHTS/FLIGHTS_dirty_734484.csv',
#  'FLIGHTS/FLIGHTS_dirty_734485.csv',
# ...

# %%
flights_dirty = pd.read_csv('FLIGHTS/FLIGHTS_dirty_734472.csv')
flights_dirty
# Out:
#       RowId           Source           Flight  ScheduledDeparture  \
# 0         0               ua  UA-2708-EWR-CLT  Thu_ Dec 1 2:55 PM
# 1         1  airtravelcenter  UA-2708-EWR-CLT                 NaN
# 2         2       myrateplan  UA-2708-EWR-CLT                 NaN
# 3         3      helloflight  UA-2708-EWR-CLT                 NaN
# 4         4        flytecomm  UA-2708-EWR-CLT                 NaN
# ...     ...              ...              ...                 ...
# 2562   2562      foxbusiness    CO-52-IAH-LAX                 NaN
# 2563   2563     allegiantair    CO-52-IAH-LAX                 NaN
# 2564   2564           boston    CO-52-IAH-LAX                 NaN
# 2565   2565           orbitz    CO-52-IAH-LAX          7:35aDec 1
# 2566   2566    flightarrival    CO-52-IAH-LAX                 NaN
#
#                ActualDeparture DepartureGate    ScheduledArrival  \
# 0           Thu_ Dec 1 2:55 PM           A37  Thu_ Dec 1 4:53 PM
# ...

# %%
flights_clean = pd.read_csv('FLIGHTS/FLIGHTS_clean_734472.csv')
flights_clean
# Out:
#       RowId           Source           Flight            ScheduledDeparture  \
# 0         0               ua  UA-2708-EWR-CLT            Thu_ Dec 1 2:55 PM
# 1         1  airtravelcenter  UA-2708-EWR-CLT            Thu_ Dec 1 2:55 PM
# 2         2       myrateplan  UA-2708-EWR-CLT            Thu_ Dec 1 2:55 PM
# 3         3      helloflight  UA-2708-EWR-CLT            Thu_ Dec 1 2:55 PM
# 4         4        flytecomm  UA-2708-EWR-CLT            Thu_ Dec 1 2:55 PM
# ...     ...              ...              ...                           ...
# 2562   2562      foxbusiness    CO-52-IAH-LAX  Thu._ Dec.01_ 2011 7:35 a.m.
# 2563   2563     allegiantair    CO-52-IAH-LAX  Thu._ Dec.01_ 2011 7:35 a.m.
# 2564   2564           boston    CO-52-IAH-LAX  Thu._ Dec.01_ 2011 7:35 a.m.
# 2565   2565           orbitz    CO-52-IAH-LAX  Thu._ Dec.01_ 2011 7:35 a.m.
# 2566   2566    flightarrival    CO-52-IAH-LAX  Thu._ Dec.01_ 2011 7:35 a.m.
#
#                    ActualDeparture DepartureGate  \
# ...
